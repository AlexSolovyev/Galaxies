# %%
import pandas as pd

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
# !python main_train_and_impute.py --epochs 3000 --latent_dim 10 --p 0.99 --output_dir 'data'
# Out:
# WARNING:tensorflow:From /LAMBDA/EDDI/p_vae.py:17: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# main_train_and_impute.py:63: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   Data = Data.as_matrix()
# number of 0s (missing): 2132
# number of 1s (observed)  4952
# WARNING:tensorflow:From /LAMBDA/EDDI/p_vae.py:65: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
# !python main_train_and_impute.py --epochs 3000 --latent_dim 10 --data_dir .'./Data/DATA.csv'
# Out:
# WARNING:tensorflow:From /Galaxies/Clustering/p_vae.py:17: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# main_train_and_impute.py:22: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   Data = Data.as_matrix()
# number of 0s (missing): 264221054.0
# number of 1s (observed)  245384970.0
# WARNING:tensorflow:From /Galaxies/Clustering/p_vae.py:65: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...
